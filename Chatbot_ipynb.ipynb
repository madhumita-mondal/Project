# %% [markdown]
# <a href="https://colab.research.google.com/github/madhumita-mondal/Project/blob/main/Chatbot_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
data_root = '/content/drive/My Drive/Datascience_Project/dataset/'
# Out:
# Mounted at /content/drive

# %%
# import json
# import string
# import random

import nltk
nltk.download('omw-1.4')
# import numpy as np
# from nltk.stem import WordNetLemmatizer
import tensorflow as tf
# from tensorflow.keras import Sequential
# from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")

import keras
import nltk
import pickle
import json
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation
import random
import datetime
from googlesearch import *
import webbrowser
import requests
#import libarchive
#import pydot
#import cartopy
from pycricbuzz import Cricbuzz
#from pycricbuzz import Cricbuzz
# c = Cricbuzz()
import billboard
import time
from pygame import mixer
import COVID19Py

from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# pygame 2.1.2 (SDL 2.0.16, Python 3.7.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# !pip install COVID19Py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting COVID19Py
#   Downloading COVID19Py-0.3.0.tar.gz (4.9 kB)
# Building wheels for collected packages: COVID19Py
#   Building wheel for COVID19Py (setup.py) ... done
#   Created wheel for COVID19Py: filename=COVID19Py-0.3.0-py3-none-any.whl size=4719 sha256=cdf393089ab0154967f340632bd3b9b859b82b627ddfd6f12981a88611bb9be4
#   Stored in directory: /root/.cache/pip/wheels/e9/bc/21/68d8cc9b49a6c3386135288d365e53c697087e19eaa7c893a5
# Successfully built COVID19Py
# Installing collected packages: COVID19Py
# Successfully installed COVID19Py-0.3.0

# %%
# !pip install pygame
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pygame
#   Downloading pygame-2.1.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.8 MB)
#      |████████████████████████████████| 21.8 MB 10.5 MB/s
# Installing collected packages: pygame
# Successfully installed pygame-2.1.2

# %%
# !pip install billboard.py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting billboard.py
#   Downloading billboard.py-7.0.0-py2.py3-none-any.whl (7.0 kB)
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from billboard.py) (2.23.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from billboard.py) (4.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.2.1->billboard.py) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.2.1->billboard.py) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.2.1->billboard.py) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.2.1->billboard.py) (2.10)
# Installing collected packages: billboard.py
# Successfully installed billboard.py-7.0.0

# %%
# !pip install pycricbuzz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycricbuzz
#   Downloading pycricbuzz-2.4-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pycricbuzz) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pycricbuzz) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pycricbuzz) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pycricbuzz) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pycricbuzz) (3.0.4)
# Installing collected packages: pycricbuzz
# Successfully installed pycricbuzz-2.4

# %%
# words=[]
# classes=[]
# data_x=[]
# data_y=[]
# for intent in data["intents"]:
#   for pattern in intent["patterns"]:
#     tokens = nltk.word_tokenize(pattern)
#     words.extend(tokens)
#     data_x.append(pattern)
#     data_y.append(intent["tag"])

#   if intent["tag"] not in classes:
#      classes.append(intent["tag"])

# lemmatizer= WordNetLemmatizer()

# words= [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation ]
# words=sorted(set(words))
# classes=sorted(set(classes))

words=[]
classes=[]
documents=[]
ignore=['?','!',',',"'s"]

data_file =open(data_root + 'intent_chatbot.json_old').read()
intents = json.loads(data_file)

for intent in intents['intents']:
    for pattern in intent['patterns']:
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w,intent['tag']))
        
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
            
words=[lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore]
words=sorted(list(set(words)))
classes=sorted(list(set(classes)))
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
# training = []
# out_empty = [0] * len(classes)

# #Creating the bag of words model
# for idx,doc in enumerate(data_x):
#   bow=[]
#   text= lemmatizer.lemmatize(doc.lower())
#   for word in words:
#     bow.append(1) if word in text else bow.append(0)
#     output_row = list(out_empty)
#     output_row[classes.index(data_y[idx])] = 1
#     training.append([bow,output_row])
# random.shuffle(training)
# training = np.array(training,dtype=object)
# train_x=np.array(list(training[:, 0]))
# train_y=np.array(list(training[:, 1]))
#training data
training=[]
output_empty=[0]*len(classes)

for doc in documents:
    bag=[]
    pattern=doc[0]
    pattern=[ lemmatizer.lemmatize(word.lower()) for word in pattern ]
    
    for word in words:
        if word in pattern:
            bag.append(1)
        else:
            bag.append(0)
    output_row=list(output_empty)
    output_row[classes.index(doc[1])]=1
    
    training.append([bag,output_row])
    
random.shuffle(training)
training=np.array(training)  
X_train=list(training[:,0])
y_train=list(training[:,1])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# from nltk import metrics
# from nltk.sem.evaluate import Model
# # The Neural Network Model
# model = Sequential()  
# model.add(Dense(128, input_shape = (len(train_x[0]),),activation="relu"))
# model.add(Dropout(0.5))
# model.add(Dense(64, activation="relu"))
# model.add(Dropout(0.5))
# model.add(Dense(len(train_y[0]), activation="softmax"))
# adam= tf.keras.optimizers.Adam(learning_rate=0.01,decay=1e-6)
# model.compile(loss='categorical_crossentropy',
#               optimizer=adam,
#               metrics = ["accuracy"])
# #print(model.summary())
# model.fit(x=train_x, y=train_y,epochs=150,verbose=1)

#Model
model=Sequential()
model.add(Dense(128,activation='relu',input_shape=(len(X_train[0]),)))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(y_train[0]),activation='softmax'))

adam = tf.keras.optimizers.Adam(0.001)
model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['accuracy'])
#model.fit(np.array(X_train),np.array(y_train),epochs=200,batch_size=10,verbose=1)
weights=model.fit(np.array(X_train),np.array(y_train),epochs=200,batch_size=10,verbose=1)    
model.save('mymodel.h5',weights)

from keras.models import load_model
model = load_model('mymodel.h5')
data_file =open(data_root + 'intent_chatbot.json_old').read()
intents = json.loads(data_file)
#intents = json.loads(open('intent_chatbot.json_old').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))
# Out:
# Epoch 1/200
# 12/12 [==============================] - 1s 2ms/step - loss: 3.4450 - accuracy: 0.0254
# Epoch 2/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.4315 - accuracy: 0.0169
# Epoch 3/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.4084 - accuracy: 0.0678
# Epoch 4/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.3822 - accuracy: 0.0678
# Epoch 5/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.3588 - accuracy: 0.0932
# Epoch 6/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.3405 - accuracy: 0.1017
# Epoch 7/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.3097 - accuracy: 0.1102
# Epoch 8/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.2624 - accuracy: 0.1186
# Epoch 9/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.2091 - accuracy: 0.1441
# Epoch 10/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.1975 - accuracy: 0.1102
# Epoch 11/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.1284 - accuracy: 0.1525
# Epoch 12/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.0868 - accuracy: 0.1525
# Epoch 13/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.9850 - accuracy: 0.1525
# Epoch 14/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8664 - accuracy: 0.1610
# Epoch 15/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8840 - accuracy: 0.2288
# Epoch 16/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.7042 - accuracy: 0.2797
# Epoch 17/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6410 - accuracy: 0.2966
# Epoch 18/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6117 - accuracy: 0.2627
# Epoch 19/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.5375 - accuracy: 0.3136
# Epoch 20/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4308 - accuracy: 0.3898
# Epoch 21/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2755 - accuracy: 0.3814
# Epoch 22/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2083 - accuracy: 0.4322
# Epoch 23/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1729 - accuracy: 0.4153
# Epoch 24/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.0752 - accuracy: 0.4746
# Epoch 25/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.9172 - accuracy: 0.4576
# Epoch 26/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.7925 - accuracy: 0.5000
# Epoch 27/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.8285 - accuracy: 0.5085
# Epoch 28/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6515 - accuracy: 0.5678
# Epoch 29/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5540 - accuracy: 0.6102
# Epoch 30/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5978 - accuracy: 0.5678
# Epoch 31/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5819 - accuracy: 0.5763
# Epoch 32/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5183 - accuracy: 0.5763
# Epoch 33/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4874 - accuracy: 0.5847
# Epoch 34/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4402 - accuracy: 0.6271
# Epoch 35/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.4590 - accuracy: 0.5847
# Epoch 36/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2721 - accuracy: 0.6780
# Epoch 37/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1745 - accuracy: 0.6864
# Epoch 38/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2208 - accuracy: 0.6441
# Epoch 39/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1328 - accuracy: 0.6525
# Epoch 40/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2185 - accuracy: 0.6695
# Epoch 41/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0062 - accuracy: 0.7034
# Epoch 42/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0709 - accuracy: 0.6864
# Epoch 43/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0105 - accuracy: 0.7288
# Epoch 44/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0107 - accuracy: 0.7542
# Epoch 45/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9085 - accuracy: 0.7458
# Epoch 46/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8107 - accuracy: 0.7542
# Epoch 47/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9281 - accuracy: 0.6949
# Epoch 48/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8462 - accuracy: 0.7881
# Epoch 49/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9086 - accuracy: 0.7627
# Epoch 50/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8978 - accuracy: 0.7627
# Epoch 51/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7776 - accuracy: 0.7542
# Epoch 52/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.8051
# Epoch 53/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7926 - accuracy: 0.7458
# Epoch 54/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6310 - accuracy: 0.8475
# Epoch 55/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7389 - accuracy: 0.7627
# Epoch 56/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6926 - accuracy: 0.8051
# Epoch 57/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6687 - accuracy: 0.8136
# Epoch 58/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6732 - accuracy: 0.8220
# Epoch 59/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5505 - accuracy: 0.8305
# Epoch 60/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7202 - accuracy: 0.7966
# Epoch 61/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6035 - accuracy: 0.8305
# Epoch 62/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6054 - accuracy: 0.8559
# Epoch 63/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5456 - accuracy: 0.8559
# Epoch 64/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5380 - accuracy: 0.8475
# Epoch 65/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5775 - accuracy: 0.8390
# Epoch 66/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4153 - accuracy: 0.9153
# Epoch 67/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6478 - accuracy: 0.8051
# Epoch 68/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5236 - accuracy: 0.8644
# Epoch 69/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4827 - accuracy: 0.8475
# Epoch 70/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5273 - accuracy: 0.8644
# Epoch 71/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4796 - accuracy: 0.8729
# Epoch 72/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4530 - accuracy: 0.8814
# Epoch 73/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3927 - accuracy: 0.8898
# Epoch 74/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4712 - accuracy: 0.8559
# Epoch 75/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.9153
# Epoch 76/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3958 - accuracy: 0.8814
# Epoch 77/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4806 - accuracy: 0.8729
# Epoch 78/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4456 - accuracy: 0.8814
# Epoch 79/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3956 - accuracy: 0.8729
# Epoch 80/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3724 - accuracy: 0.8898
# Epoch 81/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4525 - accuracy: 0.8814
# Epoch 82/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4106 - accuracy: 0.8898
# Epoch 83/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3605 - accuracy: 0.9068
# Epoch 84/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3475 - accuracy: 0.9322
# Epoch 85/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3455 - accuracy: 0.9322
# Epoch 86/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3748 - accuracy: 0.8644
# Epoch 87/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3525 - accuracy: 0.9068
# Epoch 88/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4152 - accuracy: 0.8729
# Epoch 89/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3307 - accuracy: 0.9237
# Epoch 90/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3566 - accuracy: 0.8983
# Epoch 91/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4453 - accuracy: 0.8559
# Epoch 92/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3409 - accuracy: 0.9068
# Epoch 93/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3779 - accuracy: 0.8898
# Epoch 94/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2442 - accuracy: 0.9492
# Epoch 95/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2876 - accuracy: 0.9153
# Epoch 96/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3361 - accuracy: 0.8814
# Epoch 97/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2456 - accuracy: 0.9237
# Epoch 98/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3068 - accuracy: 0.9492
# Epoch 99/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3240 - accuracy: 0.9068
# Epoch 100/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2957 - accuracy: 0.8983
# Epoch 101/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2684 - accuracy: 0.9153
# Epoch 102/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2097 - accuracy: 0.9576
# Epoch 103/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2403 - accuracy: 0.9237
# Epoch 104/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2428 - accuracy: 0.9322
# Epoch 105/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2803 - accuracy: 0.8814
# Epoch 106/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2232 - accuracy: 0.9492
# Epoch 107/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3032 - accuracy: 0.9153
# Epoch 108/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2248 - accuracy: 0.9407
# Epoch 109/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2073 - accuracy: 0.9153
# Epoch 110/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2591 - accuracy: 0.9153
# Epoch 111/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2176 - accuracy: 0.9661
# Epoch 112/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2600 - accuracy: 0.9237
# Epoch 113/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2579 - accuracy: 0.9237
# Epoch 114/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1987 - accuracy: 0.9407
# Epoch 115/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2138 - accuracy: 0.9237
# Epoch 116/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2033 - accuracy: 0.9492
# Epoch 117/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2062 - accuracy: 0.9237
# Epoch 118/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.9153
# Epoch 119/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2139 - accuracy: 0.9407
# Epoch 120/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1780 - accuracy: 0.9661
# Epoch 121/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2509 - accuracy: 0.9407
# Epoch 122/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2026 - accuracy: 0.9322
# Epoch 123/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1955 - accuracy: 0.9407
# Epoch 124/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2182 - accuracy: 0.9322
# Epoch 125/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2382 - accuracy: 0.9322
# Epoch 126/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2085 - accuracy: 0.9576
# Epoch 127/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2326 - accuracy: 0.9492
# Epoch 128/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2496 - accuracy: 0.9407
# Epoch 129/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2282 - accuracy: 0.9407
# Epoch 130/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2130 - accuracy: 0.9407
# Epoch 131/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2100 - accuracy: 0.9492
# Epoch 132/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2031 - accuracy: 0.9322
# Epoch 133/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2143 - accuracy: 0.9407
# Epoch 134/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.9322
# Epoch 135/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2390 - accuracy: 0.9068
# Epoch 136/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2031 - accuracy: 0.9407
# Epoch 137/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1532 - accuracy: 0.9492
# Epoch 138/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2014 - accuracy: 0.9407
# Epoch 139/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1951 - accuracy: 0.9576
# Epoch 140/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2065 - accuracy: 0.9237
# Epoch 141/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.9661
# Epoch 142/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1940 - accuracy: 0.9407
# Epoch 143/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2394 - accuracy: 0.9153
# Epoch 144/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1834 - accuracy: 0.9576
# Epoch 145/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1715 - accuracy: 0.9492
# Epoch 146/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2301 - accuracy: 0.9407
# Epoch 147/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1664 - accuracy: 0.9322
# Epoch 148/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1883 - accuracy: 0.9407
# Epoch 149/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2347 - accuracy: 0.9153
# Epoch 150/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2032 - accuracy: 0.9322
# Epoch 151/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.9407
# Epoch 152/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1094 - accuracy: 1.0000
# Epoch 153/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1807 - accuracy: 0.9661
# Epoch 154/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1456 - accuracy: 0.9492
# Epoch 155/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1478 - accuracy: 0.9576
# Epoch 156/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1503 - accuracy: 0.9661
# Epoch 157/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1222 - accuracy: 0.9661
# Epoch 158/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1684 - accuracy: 0.9576
# Epoch 159/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1130 - accuracy: 0.9746
# Epoch 160/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2445 - accuracy: 0.9322
# Epoch 161/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1802 - accuracy: 0.9237
# Epoch 162/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1253 - accuracy: 0.9831
# Epoch 163/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1326 - accuracy: 0.9576
# Epoch 164/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1573 - accuracy: 0.9576
# Epoch 165/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1220 - accuracy: 0.9661
# Epoch 166/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1428 - accuracy: 0.9576
# Epoch 167/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1458 - accuracy: 0.9492
# Epoch 168/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1146 - accuracy: 0.9746
# Epoch 169/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1155 - accuracy: 0.9661
# Epoch 170/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2136 - accuracy: 0.9237
# Epoch 171/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2035 - accuracy: 0.9492
# Epoch 172/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1893 - accuracy: 0.9492
# Epoch 173/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1113 - accuracy: 0.9661
# Epoch 174/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1726 - accuracy: 0.9407
# Epoch 175/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1837 - accuracy: 0.9576
# Epoch 176/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1107 - accuracy: 0.9831
# Epoch 177/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1370 - accuracy: 0.9661
# Epoch 178/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0966 - accuracy: 0.9661
# Epoch 179/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1145 - accuracy: 0.9831
# Epoch 180/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1043 - accuracy: 0.9661
# Epoch 181/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1470 - accuracy: 0.9407
# Epoch 182/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1242 - accuracy: 0.9746
# Epoch 183/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1294 - accuracy: 0.9746
# Epoch 184/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0906 - accuracy: 0.9915
# Epoch 185/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1747 - accuracy: 0.9322
# Epoch 186/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0982 - accuracy: 0.9746
# Epoch 187/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1446 - accuracy: 0.9576
# Epoch 188/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1162 - accuracy: 0.9576
# Epoch 189/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1645 - accuracy: 0.9407
# Epoch 190/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.9661
# Epoch 191/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0688 - accuracy: 0.9831
# Epoch 192/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1154 - accuracy: 0.9661
# Epoch 193/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9661
# Epoch 194/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1505 - accuracy: 0.9407
# Epoch 195/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1330 - accuracy: 0.9322
# Epoch 196/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1190 - accuracy: 0.9492
# Epoch 197/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1246 - accuracy: 0.9576
# Epoch 198/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0974 - accuracy: 0.9746
# Epoch 199/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1385 - accuracy: 0.9407
# Epoch 200/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.9237

# %%
# #Preprocessing the Input
# def clean_text(text):
#   tokens = nltk.word_tokenize(text)
#   tokens = [lemmatizer.lemmatize(word) for word in tokens]
#   return tokens
  
# def bag_of_words(text,vocab):
#   tokens = clean_text(text)
#   bow = [0] * len(vocab)
#   for w in tokens:
#     for idx, word in enumerate(vocab):
#       if word == w:
#         bow[idx]= 1
#   return np.array(bow)
# def pred_class(text,vocab,labels):
#   bow = bag_of_words(text,vocab)
#   result = model.predict(np.array([bow]))[0]
#   thresh = 0.5
#   y_pred = [[indx,res] for indx,res in enumerate(result) if res > thresh]
#   y_pred.sort(key = lambda x: x[1],reverse = True)
#   return_list=[]
#   for r in y_pred:
#     return_list.append(labels[r[0]])
#   return return_list
  
# def get_respose(intents_list,intents_json):
#   if len(intents_list) == 0:
#     result ="Sorry ! I dont understand"
#   else:
#     tag = intents_list[0]
#     list_of_intents = intents_json["intents"]
#     for i in list_of_intents:
#       if i["tag"] == tag:
#         result = random.choice(i["responses"])
#         break
#   return result

#Predict
def clean_up(sentence):
    sentence_words=nltk.word_tokenize(sentence)
    sentence_words=[ lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

def create_bow(sentence,words):
    sentence_words=clean_up(sentence)
    bag=list(np.zeros(len(words)))
    
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                bag[i] = 1
    return np.array(bag)

def predict_class(sentence,model):
    p=create_bow(sentence,words)
    res=model.predict(np.array([p]))[0]
    threshold=0.8
    results=[[i,r] for i,r in enumerate(res) if r>threshold]
    results.sort(key=lambda x: x[1],reverse=True)
    return_list=[]
    
    for result in results:
        return_list.append({'intent':classes[result[0]],'prob':str(result[1])})
    return return_list

def get_response(return_list,intents_json):
    
    if len(return_list)==0:
        tag='noanswer'
    else:    
        tag=return_list[0]['intent']
    if tag=='datetime':        
        print(time.strftime("%A"))
        print (time.strftime("%d %B %Y"))
        print (time.strftime("%H:%M:%S"))

    if tag=='google':
        query=input('Enter query...')
        chrome_path = r'C:\Program Files (x86)\Google\Chrome\Application\chrome.exe %s'
        for url in search(query, tld="co.in", num=1, stop = 1, pause = 2):
            webbrowser.open("https://google.com/search?q=%s" % query)
    if tag=='weather':
        api_key='987f44e8c16780be8c85e25a409ed07b'
        base_url = "http://api.openweathermap.org/data/2.5/weather?"
        city_name = input("Enter city name : ")
        complete_url = base_url + "appid=" + api_key + "&q=" + city_name
        response = requests.get(complete_url) 
        x=response.json()
        print('Present temp.: ',round(x['main']['temp']-273,2),'celcius ')
        print('Feels Like:: ',round(x['main']['feels_like']-273,2),'celcius ')
        print(x['weather'][0]['main'])
        
    if tag=='news':
        main_url = " http://newsapi.org/v2/top-headlines?country=inus&apiKey=bc88c2e1ddd440d1be2cb0788d027ae2"
        open_news_page = requests.get(main_url).json()
        article = open_news_page["articles"]
        results = [] 
          
        for ar in article: 
            results.append([ar["title"],ar["url"]]) 
          
        for i in range(10): 
            print(i + 1, results[i][0])
            print(results[i][1],'\n')
            
    if tag=='cricket':
        c = Cricbuzz()
        matches = c.matches()
        for match in matches:
            print(match['srs'],' ',match['mnum'],' ',match['status'])
    
    if tag=='song':
        chart=billboard.ChartData('hot-100')
        print('The top 10 songs at the moment are:')
        for i in range(10):
            song=chart[i]
            print(song.title,'- ',song.artist)
    if tag=='timer':        
        mixer.init()
        x=input('Minutes to timer..')
        time.sleep(float(x)*60)
        mixer.music.load('Handbell-ringing-sound-effect.mp3')
        mixer.music.play()
        
    if tag=='covid19':
        
        covid19=COVID19Py.COVID19(data_source='jhu')
        country=input('Enter Location...')
        
        if country.lower()=='world':
            latest_world=covid19.getLatest()
            print('Confirmed:',latest_world['confirmed'],' Deaths:',latest_world['deaths'])
        
        else:
                
            latest=covid19.getLocations()
            
            latest_conf=[]
            latest_deaths=[]
            for i in range(len(latest)):
                
                if latest[i]['country'].lower()== country.lower():
                    latest_conf.append(latest[i]['latest']['confirmed'])
                    latest_deaths.append(latest[i]['latest']['deaths'])
            latest_conf=np.array(latest_conf)
            latest_deaths=np.array(latest_deaths)
            print('Confirmed: ',np.sum(latest_conf),'Deaths: ',np.sum(latest_deaths))

    list_of_intents= intents_json['intents']    
    for i in list_of_intents:
        if tag==i['tag'] :
            result= random.choice(i['responses'])
    return result

def response(text):
    return_list=predict_class(text,model)
    response=get_response(return_list,intents)
    return response

while(1):
    x=input()
    print(response(x))
    if x.lower() in ['bye','goodbye','get lost','see you']:  
        break
# Out:
# hello
# Hi there, how can I help?
# Who r you?
# Sorry, can't understand you
# What is your name?
# My name is Chatter, I am a Deep-Learning chatbot. May I know your name?
# my name is Madhumita
# You have got a such a nice name.... How can I help you?
# What kind of help you up to?
# I am a general purpose chatbot. My capabilities are :
#  1. I can chat with you. Try asking me for jokes or riddles!
#  2. Ask me the date and time
#  3. I can google search for you. Use format google: your query
#  4. I can get the present weather for any city. Use format weather: city name
#  5. I can get you the top 10 trending news in India USA. Use keywords 'Latest News'
#  6. I can get you the top 10 trending songs globally. Type 'songs'
#  7. I can set a timer for you. Enter 'set a timer: minutes to timer'
#  8. I can get the present Covid stats for any country. Use 'covid 19: world' or 'covid 19: country name'
#  For suggestions to help me improve, send an email to tump.madhu@gmail.com . Thank you!!
# Wow... That's great
# Yeah!
# Tell me a joke
# What did the traffic light say to the car? "Don't look now, I'm changing."
# haha
# Glad I could make you laugh !
# Tell me another one
# What do you call a snowman with a suntan? A puddle.
# great
# Yeah!
# nice to talk to you
# It was nice talking to you as well! Come back soon!
# thanks
# My pleasure
# bye
# See you!

# %%
# #Interacting with the chatbot
# #print("Press 0 if you want to chat with our Chatbot")
# while True:
#   message = input("")
#   if message == "0":
#     break
#   intents = pred_class (message,words,classes)
#   result = get_respose(intents,data)
#   print (result)
#Self learning
print('Help me Learn?')
tag=input('Please enter general category of your question  ')
flag=-1
for i in range(len(intents['intents'])):
    if tag.lower() in intents['intents'][i]['tag']:
        intents['intents'][i]['patterns'].append(input('Enter your message: '))
        intents['intents'][i]['responses'].append(input('Enter expected reply: '))        
        flag=1

if flag==-1:
    
    intents['intents'].append (
        {'tag':tag,
         'patterns': [input('Please enter your message')],
         'responses': [input('Enter expected reply')]})
    
with open(data_root +'intents.json','w') as outfile:
    outfile.write(json.dumps(intents,indent=4))
# Out:
# Help me Learn?
# Please enter general category of your question  thanks
# Enter your message: Thaks
# Enter expected reply: Thanks
